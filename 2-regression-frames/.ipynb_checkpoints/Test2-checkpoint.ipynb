# %%
import tensorflow as tf
print(tf.__version__)

import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
# Out:
# 2.5.0-dev20201217

# %%
model = tf.keras.models.load_model('C:/Users/Lukas/Desktop/commaai-speed-challenge/2-regression-frames/model_regression_frames.h5')

# %%
IMG_DIM = (150, 150)

numbers = np.array(range(10798))
images = [img_to_array(load_img("C:/Users/Lukas/Desktop/commaai-speed-challenge/data/frames-test/"+str(img)+".jpg", target_size=IMG_DIM)) for img in numbers]
images = np.array(images)

len(images)
# Out:
# 10798

# %%
images_scaled  = images.astype('float32')
images_scaled /= 255

print(images[0].shape)
array_to_img(images[0])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x178A6E26550>

# %%
from keras.applications import vgg16
from keras.models import Model
import keras
import pandas as pd

input_shape = (150, 150, 3)
vgg = vgg16.VGG16(include_top=False, weights='imagenet', 
                                     input_shape=input_shape)

output = vgg.layers[-1].output
output = keras.layers.Flatten()(output)
vgg_model = Model(vgg.input, output)

vgg_model.trainable = False
for layer in vgg_model.layers:
    layer.trainable = False

# %%
def get_bottleneck_features(model, input_imgs):
    features = model.predict(input_imgs, verbose=1)
    return features
    
features_vgg = get_bottleneck_features(vgg_model, images_scaled)
# Out:
# 338/338 [==============================] - 1211s 4s/step

# %%
predicted_speed = model.predict(features_vgg, verbose=1)
# Out:
# 338/338 [==============================] - 3s 9ms/step

# %%
with open('C:/Users/Lukas/Desktop/commaai-speed-challenge/2-regression-frames/test.txt', 'w') as f:
    for speed in predicted_speed:
        f.write(str(speed)+"\n")
